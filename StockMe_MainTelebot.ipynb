# %%
import gspread
from oauth2client.service_account import ServiceAccountCredentials
import pprint

# %%
scope = ['https://spreadsheets.google.com/feeds','https://www.googleapis.com/auth/drive']
creds = ServiceAccountCredentials.from_json_keyfile_name('My Project 21738-4d265ae50b52.json', scope)
client = gspread.authorize(creds)

# %%
sheet = client.open('Stock Market: Dow Jones').sheet1
sheet2 = client.open('Stock Market: Dow Jones').get_worksheet(1)
usernames = sheet2.get_all_records()
sheet2.get_all_records()
# Out:
# [{'Username': 'peter', 'Password': 'paul', 'Saved Tickers': 'V, MMM'},
#  {'Username': 'apple', 'Password': 'asd', 'Saved Tickers': ''}]

# %%
for i in range(0,2):
    print(usernames[i])
# Out:
# {'Username': 'peter', 'Password': 'paul', 'Saved Tickers': 'V, MMM'}
# {'Username': 'apple', 'Password': 'asd', 'Saved Tickers': ''}

# %%
pp = pprint.PrettyPrinter()
ListofDict = sheet.get_all_records()
ListofDict
# Out:
# [{'Symbol': 'MMM',
#   'Name': '3M Company',
#   'Price': 173.06,
#   'Price Open': 174.42,
#   'Close Yestersay': 174.67,
#   'High': 175.14,
#   'Low': 172.4,
#   '52-Week High': 219.75,
#   '52-Week Low': 159.32,
#   'Change': -1.61,
#   'Change in Percent': -0.92,
#   'Beta Value': 1.09,
#   'Volume': 2223279,
#   'Volume Average': 2668895,
#   'Price-Earning Ratio': 18.86,
#   'Earnings per Share': 9.18,
#   'Market Cap': 99756455212,
#   'Shares': 576427000,
#   'Currency': 'USD',
#   'Data Delay': 0,
#   '4 Weeks Ago': '#N/A',
#   '': '',
#   '3 Weeks Ago': '#N/A',
#   '2 Weeks Ago': '#N/A',
#   '1 Week Ago': '#N/A',
#   'Time': '7/19/2019 10:02:47',
#   '(Slider)': '/'},
#  {'Symbol': '',
#   'Name': '',
#   'Price': '',
#   'Price Open': '',
#   'Close Yestersay': '',
#   'High': '',
#   'Low': '',
#   '52-Week High': '',
#   '52-Week Low': '',
#   'Change': '',
#   'Change in Percent': '',
#   'Beta Value': '',
#   'Volume': '',
#   'Volume Average': '',
#   'Price-Earning Ratio': '',
#   'Earnings per Share': '',
#   'Market Cap': '',
#   'Shares': '',
#   'Currency': '',
#   'Data Delay': '',
#   '4 Weeks Ago': '',
#   '': '',
#   '3 Weeks Ago': '',
#   '2 Weeks Ago': '',
#   '1 Week Ago': '',
#   'Time': '',
#   '(Slider)': '/'},
#  {'Symbol': 'AXP',
#   'Name': 'American Express Company',
#   'Price': 128.4,
#   'Price Open': 126.69,
#   'Close Yestersay': 127.05,
#   'High': 129.09,
#   'Low': 126.66,
#   '52-Week High': 129.34,
#   '52-Week Low': 89.05,
#   'Change': 1.35,
#   'Change in Percent': 1.06,
#   'Beta Value': 1.07,
#   'Volume': 3528386,
#   'Volume Average': 2896142,
#   'Price-Earning Ratio': 17.53,
#   'Earnings per Share': 7.32,
#   'Market Cap': 107224292583,
#   'Shares': 835081000,
#   'Currency': 'USD',
#   'Data Delay': 0,
#   '4 Weeks Ago': '#N/A',
#   '': '',
#   '3 Weeks Ago': '#N/A',
#   '2 Weeks Ago': '#N/A',
#   '1 Week Ago': '#N/A',
#   'Time': '',
#   '(Slider)': '/'},
#  {'Symbol': '',
#   'Name': '',
#   'Price': '',
#   'Price Open': '',
#   'Close Yestersay': '',
#   'High': '',
#   'Low': '',
#   '52-Week High': '',
#   '52-Week Low': '',
#   'Change': '',
#   'Change in Percent': '',
#   'Beta Value': '',
#   'Volume': '',
#   'Volume Average': '',
#   'Price-Earning Ratio': '',
#   'Earnings per Share': '',
#   'Market Cap': '',
#   'Shares': '',
#   'Currency': '',
#   'Data Delay': '',
#   '4 Weeks Ago': '',
#   '': '',
#   '3 Weeks Ago': '',
#   '2 Weeks Ago': '',
#   '1 Week Ago': '',
#   'Time': '',
#   '(Slider)': '/'},
#  {'Symbol': 'AAPL',
#   'Name': 'Apple Inc.',
#   'Price': 205.66,
#   'Price Open': 204,
#   'Close Yestersay': 203.35,
#   'High': 205.88,
#   'Low': 203.7,
#   '52-Week High': 233.47,
#   '52-Week Low': 142,
#   'Change': 2.31,
#   'Change in Percent': 1.14,
#   'Beta Value': 1.23,
#   'Volume': 18582161,
#   'Volume Average': 22208559,
#   'Price-Earning Ratio': 16.85,
#   'Earnings per Share': 12.21,
#   'Market Cap': 946257101349,
#   'Shares': 4601075000,
#   'Currency': 'USD',
#   'Data Delay': 0,
#   '4 Weeks Ago': '#N/A',
#   '': '',
#   '3 Weeks Ago': '#N/A',
#   '2 Weeks Ago': '#N/A',
#   '1 Week Ago': '#N/A',
#   'Time': '',
#   '(Slider)': '/'},
#  {'Symbol': '',
#   'Name': '',
#   'Price': '',
#   'Price Open': '',
#   'Close Yestersay': '',
#   'High': '',
#   'Low': '',
#   '52-Week High': '',
#   '52-Week Low': '',
#   'Change': '',
#   'Change in Percent': '',
#   'Beta Value': '',
#   'Volume': '',
#   'Volume Average': '',
#   'Price-Earning Ratio': '',
#   'Earnings per Share': '',
#   'Market Cap': '',
#   'Shares': '',
#   'Currency': '',
#   'Data Delay': '',
#   '4 Weeks Ago': '',
#   '': '',
#   '3 Weeks Ago': '',
#   '2 Weeks Ago': '',
#   '1 Week Ago': '',
#   'Time': '',
#   '(Slider)': '/'},
#  {'Symbol': 'CAT',
#   'Name': 'Caterpillar Inc.',
#   'Price': 134.89,
#   'Price Open': 134.87,
#   'Close Yestersay': 135.75,
#   'High': 135.93,
#   'Low': 134.04,
#   '52-Week High': 159.37,
#   '52-Week Low': 112.06,
#   'Change': -0.86,
#   'Change in Percent': -0.63,
#   'Beta Value': 1.54,
#   'Volume': 3552126,
#   'Volume Average': 3813626,
#   'Price-Earning Ratio': 13.38,
#   'Earnings per Share': 10.08,
#   'Market Cap': 77140353290,
#   'Shares': 571876000,
#   'Currency': 'USD',
#   'Data Delay': 0,
#   '4 Weeks Ago': '#N/A',
#   '': '',
#   '3 Weeks Ago': '#N/A',
#   '2 Weeks Ago': '#N/A',
#   '1 Week Ago': '#N/A',
#   'Time': '',
#   '(Slider)': '/'},
#  {'Symbol': '',
#   'Name': '',
#   'Price': '',
#   'Price Open': '',
#   'Close Yestersay': '',
#   'High': '',
#   'Low': '',
#   '52-Week High': '',
#   '52-Week Low': '',
#   'Change': '',
#   'Change in Percent': '',
#   'Beta Value': '',
#   'Volume': '',
#   'Volume Average': '',
#   'Price-Earning Ratio': '',
#   'Earnings per Share': '',
#   'Market Cap': '',
#   'Shares': '',
#   'Currency': '',
#   'Data Delay': '',
#   '4 Weeks Ago': '',
#   '': '',
#   '3 Weeks Ago': '',
#   '2 Weeks Ago': '',
#   '1 Week Ago': '',
#   'Time': '',
#   '(Slider)': '/'},
#  {'Symbol': 'CVX',
#   'Name': 'Chevron Corporation',
#   'Price': 124.68,
#   'Price Open': 124.12,
#   'Close Yestersay': 124.14,
#   'High': 125.05,
#   'Low': 123.36,
#   '52-Week High': 128.55,
#   '52-Week Low': 100.22,
#   'Change': 0.54,
#   'Change in Percent': 0.43,
#   'Beta Value': 0.99,
#   'Volume': 5771087,
#   'Volume Average': 5031208,
#   'Price-Earning Ratio': 16.13,
#   'Earnings per Share': 7.73,
#   'Market Cap': 237504428741,
#   'Shares': 1904912000,
#   'Currency': 'USD',
#   'Data Delay': 0,
#   '4 Weeks Ago': '#N/A',
#   '': '',
#   '3 Weeks Ago': '#N/A',
#   '2 Weeks Ago': '#N/A',
#   '1 Week Ago': '#N/A',
#   'Time': '',
#   '(Slider)': '/'},
#  {'Symbol': '',
#   'Name': '',
#   'Price': '',
#   'Price Open': '',
#   'Close Yestersay': '',
#   'High': '',
#   'Low': '',
#   '52-Week High': '',
#   '52-Week Low': '',
#   'Change': '',
#   'Change in Percent': '',
#   'Beta Value': '',
#   'Volume': '',
#   'Volume Average': '',
#   'Price-Earning Ratio': '',
#   'Earnings per Share': '',
#   'Market Cap': '',
#   'Shares': '',
#   'Currency': '',
#   'Data Delay': '',
#   '4 Weeks Ago': '',
#   '': '',
#   '3 Weeks Ago': '',
#   '2 Weeks Ago': '',
#   '1 Week Ago': '',
#   'Time': '',
#   '(Slider)': '/'},
#  {'Symbol': 'CSCO',
#   'Name': 'Cisco Systems, Inc.',
#   'Price': 57.74,
#   'Price Open': 57.05,
#   'Close Yestersay': 57.21,
#   'High': 57.79,
#   'Low': 56.9,
#   '52-Week High': 58.26,
#   '52-Week Low': 40.25,
#   'Change': 0.53,
#   'Change in Percent': 0.93,
#   'Beta Value': 1.17,
#   'Volume': 10292940,
#   'Volume Average': 22759214,
#   'Price-Earning Ratio': 20.12,
#   'Earnings per Share': 2.87,
#   'Market Cap': 247169530605,
#   'Shares': 4280733000,
#   'Currency': 'USD',
#   'Data Delay': 0,
#   '4 Weeks Ago': '#N/A',
#   '': '',
#   '3 Weeks Ago': '#N/A',
#   '2 Weeks Ago': '#N/A',
#   '1 Week Ago': '#N/A',
#   'Time': '',
#   '(Slider)': '/'},
#  {'Symbol': '',
#   'Name': '',
#   'Price': '',
#   'Price Open': '',
#   'Close Yestersay': '',
#   'High': '',
#   'Low': '',
#   '52-Week High': '',
#   '52-Week Low': '',
#   'Change': '',
#   'Change in Percent': '',
#   'Beta Value': '',
#   'Volume': '',
#   'Volume Average': '',
#   'Price-Earning Ratio': '',
#   'Earnings per Share': '',
#   'Market Cap': '',
#   'Shares': '',
#   'Currency': '',
#   'Data Delay': '',
#   '4 Weeks Ago': '',
#   '': '',
#   '3 Weeks Ago': '',
#   '2 Weeks Ago': '',
#   '1 Week Ago': '',
#   'Time': '',
#   '(Slider)': '/'},
#  {'Symbol': 'DWDP',
#   'Name': 'DowDuPont Inc.',
#   'Price': '#N/A',
#   'Price Open': '#N/A',
#   'Close Yestersay': '#N/A',
#   'High': '#N/A',
#   'Low': '#N/A',
#   '52-Week High': '#N/A',
#   '52-Week Low': '#N/A',
#   'Change': '#N/A',
#   'Change in Percent': '#N/A',
#   'Beta Value': '#N/A',
#   'Volume': '#N/A',
#   'Volume Average': '#N/A',
#   'Price-Earning Ratio': '#N/A',
#   'Earnings per Share': '#N/A',
#   'Market Cap': '#N/A',
#   'Shares': '#N/A',
#   'Currency': '#N/A',
#   'Data Delay': '#N/A',
#   '4 Weeks Ago': '#N/A',
#   '': '',
#   '3 Weeks Ago': '#N/A',
#   '2 Weeks Ago': '#N/A',
#   '1 Week Ago': '#N/A',
#   'Time': '',
#   '(Slider)': '/'},
#  {'Symbol': '',
#   'Name': '',
#   'Price': '',
#   'Price Open': '',
#   'Close Yestersay': '',
#   'High': '',
#   'Low': '',
#   '52-Week High': '',
#   '52-Week Low': '',
#   'Change': '',
#   'Change in Percent': '',
#   'Beta Value': '',
#   'Volume': '',
#   'Volume Average': '',
#   'Price-Earning Ratio': '',
#   'Earnings per Share': '',
#   'Market Cap': '',
#   'Shares': '',
#   'Currency': '',
#   'Data Delay': '',
#   '4 Weeks Ago': '',
#   '': '',
#   '3 Weeks Ago': '',
#   '2 Weeks Ago': '',
#   '1 Week Ago': '',
#   'Time': '',
#   '(Slider)': '/'},
#  {'Symbol': 'XOM',
#   'Name': 'Exxon Mobil Corporation',
#   'Price': 74.84,
#   'Price Open': 75.03,
#   'Close Yestersay': 75.48,
#   'High': 75.27,
#   'Low': 74.18,
#   '52-Week High': 87.36,
#   '52-Week Low': 64.65,
#   'Change': -0.64,
#   'Change in Percent': -0.85,
#   'Beta Value': 0.97,
#   'Volume': 11425663,
#   'Volume Average': 9728324,
#   'Price-Earning Ratio': 15.55,
#   'Earnings per Share': 4.81,
#   'Market Cap': 316655059465,
#   'Shares': 4231094000,
#   'Currency': 'USD',
#   'Data Delay': 0,
#   '4 Weeks Ago': '#N/A',
#   '': '',
#   '3 Weeks Ago': '#N/A',
#   '2 Weeks Ago': '#N/A',
#   '1 Week Ago': '#N/A',
#   'Time': '',
#   '(Slider)': '/'},
#  {'Symbol': '',
#   'Name': '',
#   'Price': '',
#   'Price Open': '',
#   'Close Yestersay': '',
#   'High': '',
#   'Low': '',
#   '52-Week High': '',
#   '52-Week Low': '',
#   'Change': '',
#   'Change in Percent': '',
#   'Beta Value': '',
#   'Volume': '',
#   'Volume Average': '',
#   'Price-Earning Ratio': '',
#   'Earnings per Share': '',
#   'Market Cap': '',
#   'Shares': '',
#   'Currency': '',
#   'Data Delay': '',
#   '4 Weeks Ago': '',
#   '': '',
#   '3 Weeks Ago': '',
#   '2 Weeks Ago': '',
#   '1 Week Ago': '',
#   'Time': '',
#   '(Slider)': '/'},
#  {'Symbol': 'INTC',
#   'Name': 'Intel Corporation',
#   'Price': 49.94,
#   'Price Open': 49.28,
#   'Close Yestersay': 49.39,
#   'High': 49.99,
#   'Low': 48.89,
#   '52-Week High': 59.59,
#   '52-Week Low': 42.36,
#   'Change': 0.55,
#   'Change in Percent': 1.11,
#   'Beta Value': 0.84,
#   'Volume': 15679636,
#   'Volume Average': 18512746,
#   'Price-Earning Ratio': 11.31,
#   'Earnings per Share': 4.41,
#   'Market Cap': 223581373851,
#   'Shares': 4477000000,
#   'Currency': 'USD',
#   'Data Delay': 0,
#   '4 Weeks Ago': '#N/A',
#   '': '',
#   '3 Weeks Ago': '#N/A',
#   '2 Weeks Ago': '#N/A',
#   '1 Week Ago': '#N/A',
#   'Time': '',
#   '(Slider)': '/'},
#  {'Symbol': '',
#   'Name': '',
#   'Price': '',
#   'Price Open': '',
#   'Close Yestersay': '',
#   'High': '',
#   'Low': '',
#   '52-Week High': '',
#   '52-Week Low': '',
#   'Change': '',
#   'Change in Percent': '',
#   'Beta Value': '',
#   'Volume': '',
#   'Volume Average': '',
#   'Price-Earning Ratio': '',
#   'Earnings per Share': '',
#   'Market Cap': '',
#   'Shares': '',
#   'Currency': '',
#   'Data Delay': '',
#   '4 Weeks Ago': '',
#   '': '',
#   '3 Weeks Ago': '',
#   '2 Weeks Ago': '',
#   '1 Week Ago': '',
#   'Time': '',
#   '(Slider)': '/'},
#  {'Symbol': 'IBM',
#   'Name': 'International Business Machines Corporation',
#   'Price': 149.63,
#   'Price Open': 142.5,
#   'Close Yestersay': 143.07,
#   'High': 150.31,
#   'Low': 142.2,
#   '52-Week High': 154.36,
#   '52-Week Low': 105.94,
#   'Change': 6.56,
#   'Change in Percent': 4.59,
#   'Beta Value': 1.25,
#   'Volume': 12695387,
#   'Volume Average': 2937553,
#   'Price-Earning Ratio': 12.74,
#   'Earnings per Share': 11.74,
#   'Market Cap': 132668396419,
#   'Shares': 886643000,
#   'Currency': 'USD',
#   'Data Delay': 0,
#   '4 Weeks Ago': '#N/A',
#   '': '',
#   '3 Weeks Ago': '#N/A',
#   '2 Weeks Ago': '#N/A',
#   '1 Week Ago': '#N/A',
#   'Time': '',
#   '(Slider)': '/'},
#  {'Symbol': '',
#   'Name': '',
#   'Price': '',
#   'Price Open': '',
#   'Close Yestersay': '',
#   'High': '',
#   'Low': '',
#   '52-Week High': '',
#   '52-Week Low': '',
#   'Change': '',
#   'Change in Percent': '',
#   'Beta Value': '',
#   'Volume': '',
#   'Volume Average': '',
#   'Price-Earning Ratio': '',
#   'Earnings per Share': '',
#   'Market Cap': '',
#   'Shares': '',
#   'Currency': '',
#   'Data Delay': '',
#   '4 Weeks Ago': '',
#   '': '',
#   '3 Weeks Ago': '',
#   '2 Weeks Ago': '',
#   '1 Week Ago': '',
#   'Time': '',
#   '(Slider)': '/'},
#  {'Symbol': 'JNJ',
#   'Name': 'Johnson & Johnson',
#   'Price': 132.07,
#   'Price Open': 132.13,
#   'Close Yestersay': 131.86,
#   'High': 132.51,
#   'Low': 131.17,
#   '52-Week High': 148.99,
#   '52-Week Low': 121,
#   'Change': 0.21,
#   'Change in Percent': 0.16,
#   'Beta Value': 0.7,
#   'Volume': 6203739,
#   'Volume Average': 7338265,
#   'Price-Earning Ratio': 21.9,
#   'Earnings per Share': 6.03,
#   'Market Cap': 350653265366,
#   'Shares': 2655056000,
#   'Currency': 'USD',
#   'Data Delay': 0,
#   '4 Weeks Ago': '#N/A',
#   '': '',
#   '3 Weeks Ago': '#N/A',
#   '2 Weeks Ago': '#N/A',
#   '1 Week Ago': '#N/A',
#   'Time': '',
#   '(Slider)': '/'},
#  {'Symbol': '',
#   'Name': '',
#   'Price': '',
#   'Price Open': '',
#   'Close Yestersay': '',
#   'High': '',
#   'Low': '',
#   '52-Week High': '',
#   '52-Week Low': '',
#   'Change': '',
#   'Change in Percent': '',
#   'Beta Value': '',
#   'Volume': '',
#   'Volume Average': '',
#   'Price-Earning Ratio': '',
#   'Earnings per Share': '',
#   'Market Cap': '',
#   'Shares': '',
#   'Currency': '',
#   'Data Delay': '',
#   '4 Weeks Ago': '',
#   '': '',
#   '3 Weeks Ago': '',
#   '2 Weeks Ago': '',
#   '1 Week Ago': '',
#   'Time': '',
#   '(Slider)': '/'},
#  {'Symbol': 'JPM',
#   'Name': 'JPMorgan Chase & Co.',
#   'Price': 114.67,
#   'Price Open': 113.93,
#   'Close Yestersay': 113.99,
#   'High': 115.07,
#   'Low': 113.55,
#   '52-Week High': 119.24,
#   '52-Week Low': 91.11,
#   'Change': 0.68,
#   'Change in Percent': 0.6,
#   'Beta Value': 1.15,
#   'Volume': 9400654,
#   'Volume Average': 11729918,
#   'Price-Earning Ratio': 11.71,
#   'Earnings per Share': 9.79,
#   'Market Cap': 371986377970,
#   'Shares': 3243973000,
#   'Currency': 'USD',
#   'Data Delay': 0,
#   '4 Weeks Ago': '#N/A',
#   '': '',
#   '3 Weeks Ago': '#N/A',
#   '2 Weeks Ago': '#N/A',
#   '1 Week Ago': '#N/A',
#   'Time': '',
#   '(Slider)': '/'},
#  {'Symbol': '',
#   'Name': '',
#   'Price': '',
#   'Price Open': '',
#   'Close Yestersay': '',
#   'High': '',
#   'Low': '',
#   '52-Week High': '',
#   '52-Week Low': '',
#   'Change': '',
#   'Change in Percent': '',
#   'Beta Value': '',
#   'Volume': '',
#   'Volume Average': '',
#   'Price-Earning Ratio': '',
#   'Earnings per Share': '',
#   'Market Cap': '',
#   'Shares': '',
#   'Currency': '',
#   'Data Delay': '',
#   '4 Weeks Ago': '',
#   '': '',
#   '3 Weeks Ago': '',
#   '2 Weeks Ago': '',
#   '1 Week Ago': '',
#   'Time': '',
#   '(Slider)': '/'},
#  {'Symbol': 'MCD',
#   'Name': "McDonald's Corporation",
#   'Price': 215.91,
#   'Price Open': 214.08,
#   'Close Yestersay': 213.71,
#   'High': 215.95,
#   'Low': 213.33,
#   '52-Week High': 215.95,
#   '52-Week Low': 153.13,
#   'Change': 2.2,
#   'Change in Percent': 1.03,
#   'Beta Value': 0.51,
#   'Volume': 2261628,
#   'Volume Average': 2745665,
#   'Price-Earning Ratio': 28.27,
#   'Earnings per Share': 7.64,
#   'Market Cap': 164859378756,
#   'Shares': 763556000,
#   'Currency': 'USD',
#   'Data Delay': 0,
#   '4 Weeks Ago': '#N/A',
#   '': '',
#   '3 Weeks Ago': '#N/A',
#   '2 Weeks Ago': '#N/A',
#   '1 Week Ago': '#N/A',
#   'Time': '',
#   '(Slider)': '/'},
#  {'Symbol': '',
#   'Name': '',
#   'Price': '',
#   'Price Open': '',
#   'Close Yestersay': '',
#   'High': '',
#   'Low': '',
#   '52-Week High': '',
#   '52-Week Low': '',
#   'Change': '',
#   'Change in Percent': '',
#   'Beta Value': '',
#   'Volume': '',
#   'Volume Average': '',
#   'Price-Earning Ratio': '',
#   'Earnings per Share': '',
#   'Market Cap': '',
#   'Shares': '',
#   'Currency': '',
#   'Data Delay': '',
#   '4 Weeks Ago': '',
#   '': '',
#   '3 Weeks Ago': '',
#   '2 Weeks Ago': '',
#   '1 Week Ago': '',
#   'Time': '',
#   '(Slider)': '/'},
#  {'Symbol': 'MRK',
#   'Name': 'Merck & Co., Inc.',
#   'Price': 82.69,
#   'Price Open': 82.41,
#   'Close Yestersay': 81.92,
#   'High': 82.96,
#   'Low': 81.6,
#   '52-Week High': 87.07,
#   '52-Week Low': 62.01,
#   'Change': 0.77,
#   'Change in Percent': 0.94,
#   'Beta Value': 0.57,
#   'Volume': 8084732,
#   'Volume Average': 11210567,
#   'Price-Earning Ratio': 34.03,
#   'Earnings per Share': 2.43,
#   'Market Cap': 212897318645,
#   'Shares': 2574644000,
#   'Currency': 'USD',
#   'Data Delay': 0,
#   '4 Weeks Ago': '#N/A',
#   '': '',
#   '3 Weeks Ago': '#N/A',
#   '2 Weeks Ago': '#N/A',
#   '1 Week Ago': '#N/A',
#   'Time': '',
#   '(Slider)': '/'},
#  {'Symbol': '',
#   'Name': '',
#   'Price': '',
#   'Price Open': '',
#   'Close Yestersay': '',
#   'High': '',
#   'Low': '',
#   '52-Week High': '',
#   '52-Week Low': '',
#   'Change': '',
#   'Change in Percent': '',
#   'Beta Value': '',
#   'Volume': '',
#   'Volume Average': '',
#   'Price-Earning Ratio': '',
#   'Earnings per Share': '',
#   'Market Cap': '',
#   'Shares': '',
#   'Currency': '',
#   'Data Delay': '',
#   '4 Weeks Ago': '',
#   '': '',
#   '3 Weeks Ago': '',
#   '2 Weeks Ago': '',
#   '1 Week Ago': '',
#   'Time': '',
#   '(Slider)': '/'},
#  {'Symbol': 'MSFT',
#   'Name': 'Microsoft Corporation',
#   'Price': 136.42,
#   'Price Open': 135.55,
#   'Close Yestersay': 136.27,
#   'High': 136.62,
#   'Low': 134.67,
#   '52-Week High': 139.54,
#   '52-Week Low': 93.96,
#   'Change': 0.15,
#   'Change in Percent': 0.11,
#   'Beta Value': 1.21,
#   'Volume': 30808707,
#   'Volume Average': 22413704,
#   'Price-Earning Ratio': 35.12,
#   'Earnings per Share': 3.88,
#   'Market Cap': 1045361617528,
#   'Shares': 7662818000,
#   'Currency': 'USD',
#   'Data Delay': 0,
#   '4 Weeks Ago': '#N/A',
#   '': '',
#   '3 Weeks Ago': '#N/A',
#   '2 Weeks Ago': '#N/A',
#   '1 Week Ago': '#N/A',
#   'Time': '',
#   '(Slider)': '/'},
#  {'Symbol': '',
#   'Name': '',
#   'Price': '',
#   'Price Open': '',
#   'Close Yestersay': '',
#   'High': '',
#   'Low': '',
#   '52-Week High': '',
#   '52-Week Low': '',
#   'Change': '',
#   'Change in Percent': '',
#   'Beta Value': '',
#   'Volume': '',
#   'Volume Average': '',
#   'Price-Earning Ratio': '',
#   'Earnings per Share': '',
#   'Market Cap': '',
#   'Shares': '',
#   'Currency': '',
#   'Data Delay': '',
#   '4 Weeks Ago': '',
#   '': '',
#   '3 Weeks Ago': '',
#   '2 Weeks Ago': '',
#   '1 Week Ago': '',
#   'Time': '',
#   '(Slider)': '/'},
#  {'Symbol': 'NKE',
#   'Name': 'NIKE, Inc.',
#   'Price': 87.44,
#   'Price Open': 87.63,
#   'Close Yestersay': 87.5,
#   'High': 87.76,
#   'Low': 86.76,
#   '52-Week High': 90,
#   '52-Week Low': 66.53,
#   'Change': -0.06,
#   'Change in Percent': -0.07,
#   'Beta Value': 0.78,
#   'Volume': 4609157,
#   'Volume Average': 6039697,
#   'Price-Earning Ratio': 35.12,
#   'Earnings per Share': 2.49,
#   'Market Cap': 109888037068,
#   'Shares': 1256725000,
#   'Currency': 'USD',
#   'Data Delay': 0,
#   '4 Weeks Ago': '#N/A',
#   '': '',
#   '3 Weeks Ago': '#N/A',
#   '2 Weeks Ago': '#N/A',
#   '1 Week Ago': '#N/A',
#   'Time': '',
#   '(Slider)': '/'},
#  {'Symbol': '',
#   'Name': '',
#   'Price': '',
#   'Price Open': '',
#   'Close Yestersay': '',
#   'High': '',
#   'Low': '',
#   '52-Week High': '',
#   '52-Week Low': '',
#   'Change': '',
#   'Change in Percent': '',
#   'Beta Value': '',
#   'Volume': '',
#   'Volume Average': '',
#   'Price-Earning Ratio': '',
#   'Earnings per Share': '',
#   'Market Cap': '',
#   'Shares': '',
#   'Currency': '',
#   'Data Delay': '',
#   '4 Weeks Ago': '',
#   '': '',
#   '3 Weeks Ago': '',
#   '2 Weeks Ago': '',
#   '1 Week Ago': '',
#   'Time': '',
#   '(Slider)': '/'},
#  {'Symbol': 'PFE',
#   'Name': 'Pfizer Inc.',
#   'Price': 43.06,
#   'Price Open': 42.86,
#   'Close Yestersay': 42.74,
#   'High': 43.06,
#   'Low': 42.55,
#   '52-Week High': 46.47,
#   '52-Week Low': 37.12,
#   'Change': 0.32,
#   'Change in Percent': 0.75,
#   'Beta Value': 0.64,
#   'Volume': 13025669,
#   'Volume Average': 21134855,
#   'Price-Earning Ratio': 24.88,
#   'Earnings per Share': 1.73,
#   'Market Cap': 239410550375,
#   'Shares': 5551805000,
#   'Currency': 'USD',
#   'Data Delay': 0,
#   '4 Weeks Ago': '#N/A',
#   '': '',
#   '3 Weeks Ago': '#N/A',
#   '2 Weeks Ago': '#N/A',
#   '1 Week Ago': '#N/A',
#   'Time': '',
#   '(Slider)': '/'},
#  {'Symbol': '',
#   'Name': '',
#   'Price': '',
#   'Price Open': '',
#   'Close Yestersay': '',
#   'High': '',
#   'Low': '',
#   '52-Week High': '',
#   '52-Week Low': '',
#   'Change': '',
#   'Change in Percent': '',
#   'Beta Value': '',
#   'Volume': '',
#   'Volume Average': '',
#   'Price-Earning Ratio': '',
#   'Earnings per Share': '',
#   'Market Cap': '',
#   'Shares': '',
#   'Currency': '',
#   'Data Delay': '',
#   '4 Weeks Ago': '',
#   '': '',
#   '3 Weeks Ago': '',
#   '2 Weeks Ago': '',
#   '1 Week Ago': '',
#   'Time': '',
#   '(Slider)': '/'},
#  {'Symbol': 'BA',
#   'Name': 'The Boeing Company',
#   'Price': 361.11,
#   'Price Open': 367.6,
#   'Close Yestersay': 369.6,
#   'High': 368.45,
#   'Low': 359.75,
#   '52-Week High': 446.01,
#   '52-Week Low': 292.47,
#   'Change': -8.49,
#   'Change in Percent': -2.3,
#   'Beta Value': 1.3,
#   'Volume': 4615218,
#   'Volume Average': 3970824,
#   'Price-Earning Ratio': 20.23,
#   'Earnings per Share': 17.85,
#   'Market Cap': 203171311058,
#   'Shares': 562630000,
#   'Currency': 'USD',
#   'Data Delay': 0,
#   '4 Weeks Ago': '#N/A',
#   '': '',
#   '3 Weeks Ago': '#N/A',
#   '2 Weeks Ago': '#N/A',
#   '1 Week Ago': '#N/A',
#   'Time': '',
#   '(Slider)': '/'},
#  {'Symbol': '',
#   'Name': '',
#   'Price': '',
#   'Price Open': '',
#   'Close Yestersay': '',
#   'High': '',
#   'Low': '',
#   '52-Week High': '',
#   '52-Week Low': '',
#   'Change': '',
#   'Change in Percent': '',
#   'Beta Value': '',
#   'Volume': '',
#   'Volume Average': '',
#   'Price-Earning Ratio': '',
#   'Earnings per Share': '',
#   'Market Cap': '',
#   'Shares': '',
#   'Currency': '',
#   'Data Delay': '',
#   '4 Weeks Ago': '',
#   '': '',
#   '3 Weeks Ago': '',
#   '2 Weeks Ago': '',
#   '1 Week Ago': '',
#   'Time': '',
#   '(Slider)': '/'},
#  {'Symbol': 'KO',
#   'Name': 'The Coca-Cola Company',
#   'Price': 52.03,
#   'Price Open': 52.04,
#   'Close Yestersay': 52.18,
#   'High': 52.17,
#   'Low': 51.67,
#   '52-Week High': 52.47,
#   '52-Week Low': 44.25,
#   'Change': -0.15,
#   'Change in Percent': -0.29,
#   'Beta Value': 0.5,
#   'Volume': 11912294,
#   'Volume Average': 10961050,
#   'Price-Earning Ratio': 33.42,
#   'Earnings per Share': 1.56,
#   'Market Cap': 221965958242,
#   'Shares': 4266115000,
#   'Currency': 'USD',
#   'Data Delay': 0,
#   '4 Weeks Ago': '#N/A',
#   '': '',
#   '3 Weeks Ago': '#N/A',
#   '2 Weeks Ago': '#N/A',
#   '1 Week Ago': '#N/A',
#   'Time': '',
#   '(Slider)': '/'},
#  {'Symbol': '',
#   'Name': '',
#   'Price': '',
#   'Price Open': '',
#   'Close Yestersay': '',
#   'High': '',
#   'Low': '',
#   '52-Week High': '',
#   '52-Week Low': '',
#   'Change': '',
#   'Change in Percent': '',
#   'Beta Value': '',
#   'Volume': '',
#   'Volume Average': '',
#   'Price-Earning Ratio': '',
#   'Earnings per Share': '',
#   'Market Cap': '',
#   'Shares': '',
#   'Currency': '',
#   'Data Delay': '',
#   '4 Weeks Ago': '',
#   '': '',
#   '3 Weeks Ago': '',
#   '2 Weeks Ago': '',
#   '1 Week Ago': '',
#   'Time': '',
#   '(Slider)': '/'},
#  {'Symbol': 'GS',
#   'Name': 'The Goldman Sachs Group, Inc.',
#   'Price': 214.52,
#   'Price Open': 212.71,
#   'Close Yestersay': 213.3,
#   'High': 215.83,
#   'Low': 211.75,
#   '52-Week High': 245.08,
#   '52-Week Low': 151.7,
#   'Change': 1.22,
#   'Change in Percent': 0.57,
#   'Beta Value': 1.29,
#   'Volume': 2858986,
#   'Volume Average': 2254295,
#   'Price-Earning Ratio': 8.99,
#   'Earnings per Share': 23.85,
#   'Market Cap': 78479719487,
#   'Shares': 365839000,
#   'Currency': 'USD',
#   'Data Delay': 0,
#   '4 Weeks Ago': '#N/A',
#   '': '',
#   '3 Weeks Ago': '#N/A',
#   '2 Weeks Ago': '#N/A',
#   '1 Week Ago': '#N/A',
#   'Time': '',
#   '(Slider)': '/'},
#  {'Symbol': '',
#   'Name': '',
#   'Price': '',
#   'Price Open': '',
#   'Close Yestersay': '',
#   'High': '',
#   'Low': '',
#   '52-Week High': '',
#   '52-Week Low': '',
#   'Change': '',
#   'Change in Percent': '',
#   'Beta Value': '',
#   'Volume': '',
#   'Volume Average': '',
#   'Price-Earning Ratio': '',
#   'Earnings per Share': '',
#   'Market Cap': '',
#   'Shares': '',
#   'Currency': '',
#   'Data Delay': '',
#   '4 Weeks Ago': '',
#   '': '',
#   '3 Weeks Ago': '',
#   '2 Weeks Ago': '',
#   '1 Week Ago': '',
#   'Time': '',
#   '(Slider)': '/'},
#  {'Symbol': 'HD',
#   'Name': 'The Home Depot, Inc.',
#   'Price': 214.44,
#   'Price Open': 215.5,
#   'Close Yestersay': 215.61,
#   'High': 216.23,
#   'Low': 213.01,
#   '52-Week High': 219.3,
#   '52-Week Low': 158.09,
#   'Change': -1.17,
#   'Change in Percent': -0.54,
#   'Beta Value': 1.12,
#   'Volume': 3069619,
#   'Volume Average': 3943938,
#   'Price-Earning Ratio': 21.61,
#   'Earnings per Share': 9.93,
#   'Market Cap': 235945332526,
#   'Shares': 1100286000,
#   'Currency': 'USD',
#   'Data Delay': 0,
#   '4 Weeks Ago': '#N/A',
#   '': '',
#   '3 Weeks Ago': '#N/A',
#   '2 Weeks Ago': '#N/A',
#   '1 Week Ago': '#N/A',
#   'Time': '',
#   '(Slider)': '/'},
#  {'Symbol': '',
#   'Name': '',
#   'Price': '',
#   'Price Open': '',
#   'Close Yestersay': '',
#   'High': '',
#   'Low': '',
#   '52-Week High': '',
#   '52-Week Low': '',
#   'Change': '',
#   'Change in Percent': '',
#   'Beta Value': '',
#   'Volume': '',
#   'Volume Average': '',
#   'Price-Earning Ratio': '',
#   'Earnings per Share': '',
#   'Market Cap': '',
#   'Shares': '',
#   'Currency': '',
#   'Data Delay': '',
#   '4 Weeks Ago': '',
#   '': '',
#   '3 Weeks Ago': '',
#   '2 Weeks Ago': '',
#   '1 Week Ago': '',
#   'Time': '',
#   '(Slider)': '/'},
#  {'Symbol': 'PG',
#   'Name': 'The Procter & Gamble Company',
#   'Price': 115.44,
#   'Price Open': 114.93,
#   'Close Yestersay': 115.19,
#   'High': 115.77,
#   'Low': 114.79,
#   '52-Week High': 116.52,
#   '52-Week Low': 77.54,
#   'Change': 0.25,
#   'Change in Percent': 0.21,
#   'Beta Value': 0.45,
#   'Volume': 5828782,
#   'Volume Average': 7195078,
#   'Price-Earning Ratio': 29.63,
#   'Earnings per Share': 3.9,
#   'Market Cap': 289561621323,
#   'Shares': 2508330000,
#   'Currency': 'USD',
#   'Data Delay': 0,
#   '4 Weeks Ago': '#N/A',
#   '': '',
#   '3 Weeks Ago': '#N/A',
#   '2 Weeks Ago': '#N/A',
#   '1 Week Ago': '#N/A',
#   'Time': '',
#   '(Slider)': '/'},
#  {'Symbol': '',
#   'Name': '',
#   'Price': '',
#   'Price Open': '',
#   'Close Yestersay': '',
#   'High': '',
#   'Low': '',
#   '52-Week High': '',
#   '52-Week Low': '',
#   'Change': '',
#   'Change in Percent': '',
#   'Beta Value': '',
#   'Volume': '',
#   'Volume Average': '',
#   'Price-Earning Ratio': '',
#   'Earnings per Share': '',
#   'Market Cap': '',
#   'Shares': '',
#   'Currency': '',
#   'Data Delay': '',
#   '4 Weeks Ago': '',
#   '': '',
#   '3 Weeks Ago': '',
#   '2 Weeks Ago': '',
#   '1 Week Ago': '',
#   'Time': '',
#   '(Slider)': '/'},
#  {'Symbol': 'TRV',
#   'Name': 'The Travelers Companies, Inc.',
#   'Price': 152.71,
#   'Price Open': 152.35,
#   'Close Yestersay': 152.38,
#   'High': 152.87,
#   'Low': 151.55,
#   '52-Week High': 155.09,
#   '52-Week Low': 111.08,
#   'Change': 0.33,
#   'Change in Percent': 0.22,
#   'Beta Value': 0.96,
#   'Volume': 763002,
#   'Volume Average': 1155702,
#   'Price-Earning Ratio': 16.45,
#   'Earnings per Share': 9.28,
#   'Market Cap': 39995972438,
#   'Shares': 261908000,
#   'Currency': 'USD',
#   'Data Delay': 0,
#   '4 Weeks Ago': '#N/A',
#   '': '',
#   '3 Weeks Ago': '#N/A',
#   '2 Weeks Ago': '#N/A',
#   '1 Week Ago': '#N/A',
#   'Time': '',
#   '(Slider)': '/'},
#  {'Symbol': '',
#   'Name': '',
#   'Price': '',
#   'Price Open': '',
#   'Close Yestersay': '',
#   'High': '',
#   'Low': '',
#   '52-Week High': '',
#   '52-Week Low': '',
#   'Change': '',
#   'Change in Percent': '',
#   'Beta Value': '',
#   'Volume': '',
#   'Volume Average': '',
#   'Price-Earning Ratio': '',
#   'Earnings per Share': '',
#   'Market Cap': '',
#   'Shares': '',
#   'Currency': '',
#   'Data Delay': '',
#   '4 Weeks Ago': '',
#   '': '',
#   '3 Weeks Ago': '',
#   '2 Weeks Ago': '',
#   '1 Week Ago': '',
#   'Time': '',
#   '(Slider)': '/'},
#  {'Symbol': 'DIS',
#   'Name': 'The Walt Disney Company',
#   'Price': 141.63,
#   'Price Open': 142.46,
#   'Close Yestersay': 142.57,
#   'High': 142.46,
#   'Low': 140.17,
#   '52-Week High': 145.43,
#   '52-Week Low': 100.35,
#   'Change': -0.94,
#   'Change in Percent': -0.66,
#   'Beta Value': 0.96,
#   'Volume': 8035481,
#   'Volume Average': 8760759,
#   'Price-Earning Ratio': 19.58,
#   'Earnings per Share': 7.23,
#   'Market Cap': 254891378157,
#   'Shares': 1799699000,
#   'Currency': 'USD',
#   'Data Delay': 0,
#   '4 Weeks Ago': '#N/A',
#   '': '',
#   '3 Weeks Ago': '#N/A',
#   '2 Weeks Ago': '#N/A',
#   '1 Week Ago': '#N/A',
#   'Time': '',
#   '(Slider)': '/'},
#  {'Symbol': '',
#   'Name': '',
#   'Price': '',
#   'Price Open': '',
#   'Close Yestersay': '',
#   'High': '',
#   'Low': '',
#   '52-Week High': '',
#   '52-Week Low': '',
#   'Change': '',
#   'Change in Percent': '',
#   'Beta Value': '',
#   'Volume': '',
#   'Volume Average': '',
#   'Price-Earning Ratio': '',
#   'Earnings per Share': '',
#   'Market Cap': '',
#   'Shares': '',
#   'Currency': '',
#   'Data Delay': '',
#   '4 Weeks Ago': '',
#   '': '',
#   '3 Weeks Ago': '',
#   '2 Weeks Ago': '',
#   '1 Week Ago': '',
#   'Time': '',
#   '(Slider)': '/'},
#  {'Symbol': 'UTX',
#   'Name': 'United Technologies Corporation',
#   'Price': 131.3,
#   'Price Open': 129.88,
#   'Close Yestersay': 130.1,
#   'High': 131.35,
#   'Low': 129.76,
#   '52-Week High': 144.4,
#   '52-Week Low': 100.48,
#   'Change': 1.2,
#   'Change in Percent': 0.92,
#   'Beta Value': 1.22,
#   'Volume': 2918912,
#   'Volume Average': 4070208,
#   'Price-Earning Ratio': 17.69,
#   'Earnings per Share': 7.42,
#   'Market Cap': 113218850321,
#   'Shares': 862906000,
#   'Currency': 'USD',
#   'Data Delay': 0,
#   '4 Weeks Ago': '#N/A',
#   '': '',
#   '3 Weeks Ago': '#N/A',
#   '2 Weeks Ago': '#N/A',
#   '1 Week Ago': '#N/A',
#   'Time': '',
#   '(Slider)': '/'},
#  {'Symbol': '',
#   'Name': '',
#   'Price': '',
#   'Price Open': '',
#   'Close Yestersay': '',
#   'High': '',
#   'Low': '',
#   '52-Week High': '',
#   '52-Week Low': '',
#   'Change': '',
#   'Change in Percent': '',
#   'Beta Value': '',
#   'Volume': '',
#   'Volume Average': '',
#   'Price-Earning Ratio': '',
#   'Earnings per Share': '',
#   'Market Cap': '',
#   'Shares': '',
#   'Currency': '',
#   'Data Delay': '',
#   '4 Weeks Ago': '',
#   '': '',
#   '3 Weeks Ago': '',
#   '2 Weeks Ago': '',
#   '1 Week Ago': '',
#   'Time': '',
#   '(Slider)': '/'},
#  {'Symbol': 'UNH',
#   'Name': 'UnitedHealth Group Incorporated',
#   'Price': 260.6,
#   'Price Open': 265.64,
#   'Close Yestersay': 266.65,
#   'High': 266.51,
#   'Low': 257.26,
#   '52-Week High': 287.94,
#   '52-Week Low': 208.07,
#   'Change': -6.05,
#   'Change in Percent': -2.27,
#   'Beta Value': 0.61,
#   'Volume': 5827020,
#   'Volume Average': 3639976,
#   'Price-Earning Ratio': 21.37,
#   'Earnings per Share': 12.19,
#   'Market Cap': 247659391600,
#   'Shares': 950343000,
#   'Currency': 'USD',
#   'Data Delay': 0,
#   '4 Weeks Ago': '#N/A',
#   '': '',
#   '3 Weeks Ago': '#N/A',
#   '2 Weeks Ago': '#N/A',
#   '1 Week Ago': '#N/A',
#   'Time': '',
#   '(Slider)': '/'},
#  {'Symbol': '',
#   'Name': '',
#   'Price': '',
#   'Price Open': '',
#   'Close Yestersay': '',
#   'High': '',
#   'Low': '',
#   '52-Week High': '',
#   '52-Week Low': '',
#   'Change': '',
#   'Change in Percent': '',
#   'Beta Value': '',
#   'Volume': '',
#   'Volume Average': '',
#   'Price-Earning Ratio': '',
#   'Earnings per Share': '',
#   'Market Cap': '',
#   'Shares': '',
#   'Currency': '',
#   'Data Delay': '',
#   '4 Weeks Ago': '',
#   '': '',
#   '3 Weeks Ago': '',
#   '2 Weeks Ago': '',
#   '1 Week Ago': '',
#   'Time': '',
#   '(Slider)': '/'},
#  {'Symbol': 'VZ',
#   'Name': 'Verizon Communications Inc.',
#   'Price': 57.21,
#   'Price Open': 57.22,
#   'Close Yestersay': 57.22,
#   'High': 57.32,
#   'Low': 56.78,
#   '52-Week High': 61.58,
#   '52-Week Low': 50.05,
#   'Change': -0.01,
#   'Change in Percent': -0.02,
#   'Beta Value': 0.51,
#   'Volume': 7551137,
#   'Volume Average': 12074584,
#   'Price-Earning Ratio': 15.22,
#   'Earnings per Share': 3.76,
#   'Market Cap': 236603793683,
#   'Shares': 4135707000,
#   'Currency': 'USD',
#   'Data Delay': 0,
#   '4 Weeks Ago': '#N/A',
#   '': '',
#   '3 Weeks Ago': '#N/A',
#   '2 Weeks Ago': '#N/A',
#   '1 Week Ago': '#N/A',
#   'Time': '',
#   '(Slider)': '/'},
#  {'Symbol': '',
#   'Name': '',
#   'Price': '',
#   'Price Open': '',
#   'Close Yestersay': '',
#   'High': '',
#   'Low': '',
#   '52-Week High': '',
#   '52-Week Low': '',
#   'Change': '',
#   'Change in Percent': '',
#   'Beta Value': '',
#   'Volume': '',
#   'Volume Average': '',
#   'Price-Earning Ratio': '',
#   'Earnings per Share': '',
#   'Market Cap': '',
#   'Shares': '',
#   'Currency': '',
#   'Data Delay': '',
#   '4 Weeks Ago': '',
#   '': '',
#   '3 Weeks Ago': '',
#   '2 Weeks Ago': '',
#   '1 Week Ago': '',
#   'Time': '',
#   '(Slider)': '/'},
#  {'Symbol': 'V',
#   'Name': 'Visa Inc.',
#   'Price': 180.53,
#   'Price Open': 178.63,
#   'Close Yestersay': 179.15,
#   'High': 180.62,
#   'Low': 178.58,
#   '52-Week High': 181.35,
#   '52-Week Low': 121.6,
#   'Change': 1.38,
#   'Change in Percent': 0.77,
#   'Beta Value': 0.97,
#   'Volume': 4738512,
#   'Volume Average': 7054261,
#   'Price-Earning Ratio': 40.76,
#   'Earnings per Share': 4.43,
#   'Market Cap': 394527551382,
#   'Shares': 1738988000,
#   'Currency': 'USD',
#   'Data Delay': 0,
#   '4 Weeks Ago': '#N/A',
#   '': '',
#   '3 Weeks Ago': '#N/A',
#   '2 Weeks Ago': '#N/A',
#   '1 Week Ago': '#N/A',
#   'Time': '',
#   '(Slider)': '/'},
#  {'Symbol': '',
#   'Name': '',
#   'Price': '',
#   'Price Open': '',
#   'Close Yestersay': '',
#   'High': '',
#   'Low': '',
#   '52-Week High': '',
#   '52-Week Low': '',
#   'Change': '',
#   'Change in Percent': '',
#   'Beta Value': '',
#   'Volume': '',
#   'Volume Average': '',
#   'Price-Earning Ratio': '',
#   'Earnings per Share': '',
#   'Market Cap': '',
#   'Shares': '',
#   'Currency': '',
#   'Data Delay': '',
#   '4 Weeks Ago': '',
#   '': '',
#   '3 Weeks Ago': '',
#   '2 Weeks Ago': '',
#   '1 Week Ago': '',
#   'Time': '',
#   '(Slider)': '/'},
#  {'Symbol': 'WBA',
#   'Name': 'Walgreens Boots Alliance, Inc.',
#   'Price': 54.82,
#   'Price Open': 54.3,
#   'Close Yestersay': 54.52,
#   'High': 54.96,
#   'Low': 53.82,
#   '52-Week High': 86.31,
#   '52-Week Low': 49.31,
#   'Change': 0.3,
#   'Change in Percent': 0.55,
#   'Beta Value': 0.82,
#   'Volume': 4249271,
#   'Volume Average': 5498630,
#   'Price-Earning Ratio': 10.76,
#   'Earnings per Share': 5.09,
#   'Market Cap': 49510298984,
#   'Shares': 903143000,
#   'Currency': 'USD',
#   'Data Delay': 0,
#   '4 Weeks Ago': '#N/A',
#   '': '',
#   '3 Weeks Ago': '#N/A',
#   '2 Weeks Ago': '#N/A',
#   '1 Week Ago': '#N/A',
#   'Time': '',
#   '(Slider)': '/'},
#  {'Symbol': '',
#   'Name': '',
#   'Price': '',
#   'Price Open': '',
#   'Close Yestersay': '',
#   'High': '',
#   'Low': '',
#   '52-Week High': '',
#   '52-Week Low': '',
#   'Change': '',
#   'Change in Percent': '',
#   'Beta Value': '',
#   'Volume': '',
#   'Volume Average': '',
#   'Price-Earning Ratio': '',
#   'Earnings per Share': '',
#   'Market Cap': '',
#   'Shares': '',
#   'Currency': '',
#   'Data Delay': '',
#   '4 Weeks Ago': '',
#   '': '',
#   '3 Weeks Ago': '',
#   '2 Weeks Ago': '',
#   '1 Week Ago': '',
#   'Time': '',
#   '(Slider)': '/'},
#  {'Symbol': 'WMT',
#   'Name': 'Walmart Inc.',
#   'Price': 114.72,
#   'Price Open': 114.35,
#   'Close Yestersay': 114.6,
#   'High': 114.78,
#   'Low': 113.74,
#   '52-Week High': 115.49,
#   '52-Week Low': 85.78,
#   'Change': 0.12,
#   'Change in Percent': 0.1,
#   'Beta Value': 0.41,
#   'Volume': 3224798,
#   'Volume Average': 5239780,
#   'Price-Earning Ratio': 39.74,
#   'Earnings per Share': 2.89,
#   'Market Cap': 327493711324,
#   'Shares': 2854722000,
#   'Currency': 'USD',
#   'Data Delay': 0,
#   '4 Weeks Ago': '#N/A',
#   '': '',
#   '3 Weeks Ago': '#N/A',
#   '2 Weeks Ago': '#N/A',
#   '1 Week Ago': '#N/A',
#   'Time': '',
#   '(Slider)': '/'},
#  {'Symbol': '',
#   'Name': '',
#   'Price': '',
#   'Price Open': '',
#   'Close Yestersay': '',
#   'High': '',
#   'Low': '',
#   '52-Week High': '',
#   '52-Week Low': '',
#   'Change': '',
#   'Change in Percent': '',
#   'Beta Value': '',
#   'Volume': '',
#   'Volume Average': '',
#   'Price-Earning Ratio': '',
#   'Earnings per Share': '',
#   'Market Cap': '',
#   'Shares': '',
#   'Currency': '',
#   'Data Delay': '',
#   '4 Weeks Ago': '',
#   '': '',
#   '3 Weeks Ago': '',
#   '2 Weeks Ago': '',
#   '1 Week Ago': '',
#   'Time': '',
#   '(Slider)': '/'}]

# %%
len(ListofDict)
# Out:
# 60

# %%
del ListofDict[1::2]

# %%
Dictfortickers = {}

for i in range(0,30):
    Dictfortickers[ListofDict[i]["Symbol"]]= i
    
Dictfortickers
# Out:
# {'MMM': 0,
#  'AXP': 1,
#  'AAPL': 2,
#  'CAT': 3,
#  'CVX': 4,
#  'CSCO': 5,
#  'DWDP': 6,
#  'XOM': 7,
#  'INTC': 8,
#  'IBM': 9,
#  'JNJ': 10,
#  'JPM': 11,
#  'MCD': 12,
#  'MRK': 13,
#  'MSFT': 14,
#  'NKE': 15,
#  'PFE': 16,
#  'BA': 17,
#  'KO': 18,
#  'GS': 19,
#  'HD': 20,
#  'PG': 21,
#  'TRV': 22,
#  'DIS': 23,
#  'UTX': 24,
#  'UNH': 25,
#  'VZ': 26,
#  'V': 27,
#  'WBA': 28,
#  'WMT': 29}

# %%
## the following is learned from/taken from/inspired by:
## https://www.youtube.com/watch?v=jhFsFZXZbu4&feature=youtu.be&fbclid=IwAR1j20K5V4K1v1iAtNQCMaogBdCjOpVVktaj7bXELiQR5HnKfc_wpk6vJUk

import telebot
import time

myBotToken = "849789059:AAHGJ_-j5DYZtZl5ZdRkHlHFzondHxAP9QI"
myBot = telebot.TeleBot(token = myBotToken)

# assume this to be the main dict of everything

tickerList = []
for i in Dictfortickers:
    tickerList.append(i)# make a list here of the tickers in the json-derived line
tickersString = "\n".join(tickerList) # turn into a string to send

@myBot.message_handler(commands = ['start'])
def welcome(words):
    myBot.reply_to(words, "Welcome to StockMe Bot! To get you started, here are some functions you can type in! \n\
    Type in: '/tickers' to get a full list of the tickers that are available \n\
    Type in: '/geninfo' to get general information about a ticker \nType in: '/help' to get a list of all functions\n\
    Type in: /login if you have an account and want to login \n \
    Type in: /signup if you would like to make an account")

#USERNAME SYSTEM
'''
myBot.message_handler(commands = ['login'])
def askusername(message):
    sent = myBot.send_message(message.chat.id, 'Enter your username')
    myBot.register_next_step_handler(sent, checker)
def checker(message):
    for i in range(0,len(usernames)):
        if usernames[i]["Username"] != str(message.text):
            pass
        elif usernames[i]["Username"] == str(message.text):
            sent = myBot.send_message(message.chat.id, 'Enter your password')
            myBot.register_next_step_handler(sent, passward)
            def passward(message):
                if usernames[i]["Password"]==message.text
'''    
#END OF USERNAME SYSTEM    
@myBot.message_handler(commands = ['help'])
def helpDesk(words):
    myBot.reply_to(words, "List of functions: \n"+ \
    "Type in: '/start' to restart the bot \n " +\
    "Type in: '/help' for the full list of commands \n " +\
    "Type in: '/tickers' for the list of tickers avaible\n " +\
    "Type in: '/geninfo' for general information about a ticker\n " +\
    "Type in: '/OpenClose' for the Opening Price and Closing Price Yesterday \n " +\
    "Type in: '/HiLoToday' for the High and Low Today \n" +\
    "Type in: '/HiLo52' for the High and Low from a 52-week period \n" +\
    "Type in: '/Change' for the change in percent \n" +\
    "Type in: '/Volume' for the Volume and Volume Average \n" +\
    "Type in: '/PER' for the Price Earning Ratio \n" +\
    "Type in: '/EPS' for the Earnings Per Share \n" + \
    "Type in: '/MarketCap' for the Market Cap \n" + \
    "Type in: '/Shares' for the number of Shares \n")

@myBot.message_handler(commands = ['tickers'])
def tickerList(words):
    myBot.reply_to(words, tickersString) # display each of the element of the list, use \n accordingly

## the following is taken from:
## https://stackoverflow.com/questions/44054143/save-user-input-after-certain-message-telegram-bot

@myBot.message_handler(commands=['geninfo'])
def ask(message):
    sent = myBot.send_message(message.chat.id, 'Enter stock ticker. Enter /tickers to view ticker list then enter /geninfo to return.')
    myBot.register_next_step_handler(sent, stockInfo)
def stockInfo(message):
    # optional: open('entry.txt', 'w').write(str(message.chat.id) + ' | ' + message.text + '||')
    myBot.send_message(message.chat.id,"Symbol: "+ str(ListofDict[Dictfortickers[message.text]]["Symbol"])+"\n" +\
                       "Name: " + str(ListofDict[Dictfortickers[message.text]]["Name"]) +"\n" +\
                      "Currency: " + str(ListofDict[Dictfortickers[message.text]]["Currency"]) +"\n" +\
                      "Price: " + str(ListofDict[Dictfortickers[message.text]]["Price"]) +"\n" +\
                      "Change: " + str(ListofDict[Dictfortickers[message.text]]["Change"]))
    myBot.send_message(message.chat.id,"Here are more functions for additional info on the company! \n" +\
    "Type in: '/OpenClose' for the Opening Price and Closing Price Yesterday \n " +\
    "Type in: '/HiLoToday' for the High and Low Today \n" +\
    "Type in: '/HiLo52' for the High and Low from a 52-week period \n" +\
    "Type in: '/Change' for the change in percent \n" +\
    "Type in: '/Volume' for the Volume and Volume Average \n" +\
    "Type in: '/PER' for the Price Earning Ratio \n" +\
    "Type in: '/EPS' for the Earnings Per Share \n" + \
    "Type in: '/MarketCap' for the Market Cap \n" + \
    "Type in: '/Shares' for the number of Shares \n")

#the functions
@myBot.message_handler(commands = ['OpenClose'])
def askop(message):
    sent = myBot.send_message(message.chat.id, 'Enter stock ticker. Enter /tickers to view ticker list then enter /OpenClose to return.')
    myBot.register_next_step_handler(sent, stockCO)
def stockCO(message):
    myBot.send_message(message.chat.id,"Price Open: "+ str(ListofDict[Dictfortickers[message.text]]["Price Open"]) +"\n" +\
                       "Close Yesterday: " + str(ListofDict[Dictfortickers[message.text]]["Close Yestersay"]))
    
@myBot.message_handler(commands = ['HiLoToday'])
def askhitod(message):
    sent = myBot.send_message(message.chat.id, 'Enter stock ticker. Enter /tickers to view ticker list then enter /HiLoToday to return.')
    myBot.register_next_step_handler(sent, stockhitod)
def stockhitod(message):
    myBot.send_message(message.chat.id,"High today: "+ str(ListofDict[Dictfortickers[message.text]]["High"]) +"\n" +\
                       "Low today: " + str(ListofDict[Dictfortickers[message.text]]["Low"]))
    
@myBot.message_handler(commands = ['HiLo52'])
def askhit52(message):
    sent = myBot.send_message(message.chat.id, 'Enter stock ticker. Enter /tickers to view ticker list then enter /HiLo52 to return.')
    myBot.register_next_step_handler(sent, stockhi52)
def stockhi52(message):
    myBot.send_message(message.chat.id,"52-Week High: "+ str(ListofDict[Dictfortickers[message.text]]["52-Week High"]) +"\n" +\
                       "52-Week Low: " + str(ListofDict[Dictfortickers[message.text]]["52-Week Low"]))

@myBot.message_handler(commands = ['Change'])
def askchange(message):
    sent = myBot.send_message(message.chat.id, 'Enter stock ticker. Enter /tickers to view ticker list then enter /Change to return.')
    myBot.register_next_step_handler(sent, stockchange)
def stockchange(message):
    myBot.send_message(message.chat.id,"Change: "+ str(ListofDict[Dictfortickers[message.text]]["Change"]) +"\n" +\
                       "Percent Change: " + str(ListofDict[Dictfortickers[message.text]]["Change in Percent"]))

@myBot.message_handler(commands = ['Volume'])
def askvol(message):
    sent = myBot.send_message(message.chat.id, 'Enter stock ticker. Enter /tickers to view ticker list then enter /Volume to return.')
    myBot.register_next_step_handler(sent, stockvol)
def stockvol(message):
    myBot.send_message(message.chat.id,"Volume: "+ str(ListofDict[Dictfortickers[message.text]]["Volume"]) +"\n" +\
                       "Volume Average: " + str(ListofDict[Dictfortickers[message.text]]["Volume Average"]))
    
@myBot.message_handler(commands = ['PER'])
def askper(message):
    sent = myBot.send_message(message.chat.id, 'Enter stock ticker. Enter /tickers to view ticker list then enter /PER to return.')
    myBot.register_next_step_handler(sent, stockper)
def stockper(message):
    myBot.send_message(message.chat.id,"Price-Earning Ratio: "+ str(ListofDict[Dictfortickers[message.text]]["Price-Earning Ratio"]))
    
@myBot.message_handler(commands = ['EPS'])
def askeps(message):
    sent = myBot.send_message(message.chat.id, 'Enter stock ticker. Enter /tickers to view ticker list then enter /EPS to return.')
    myBot.register_next_step_handler(sent, stockeps)
def stockeps(message):
    myBot.send_message(message.chat.id,"Earnings Per Share: "+ str(ListofDict[Dictfortickers[message.text]]["Earnings per Share"]))

@myBot.message_handler(commands = ['MarketCap'])
def askmc(message):
    sent = myBot.send_message(message.chat.id, 'Enter stock ticker. Enter /tickers to view ticker list then enter /MarketCap to return.')
    myBot.register_next_step_handler(sent, stockmc)
def stockmc(message):
    myBot.send_message(message.chat.id,"Market Cap: "+ str(ListofDict[Dictfortickers[message.text]]["Market Cap"]))

@myBot.message_handler(commands = ['Shares'])
def askshare(message):
    sent = myBot.send_message(message.chat.id, 'Enter stock ticker. Enter /tickers to view ticker list then enter /Shares to return.')
    myBot.register_next_step_handler(sent, stockshare)
def stockshare(message):
    myBot.send_message(message.chat.id,"Shares: "+ str(ListofDict[Dictfortickers[message.text]]["Shares"]))
    
## end of citation
    
while True:
    try:
        myBot.polling()
    except Exception:
        time.sleep(10)
# Out:
# 2019-07-19 10:45:55,928 (util.py:65 PollingThread) ERROR - TeleBot: "ApiException occurred, args=('A request to the Telegram API was unsuccessful. The server returned HTTP 409 Conflict. Response body:\n[b\'{"ok":false,"error_code":409,"description":"Conflict: terminated by other getUpdates request; make sure that only one bot instance is running"}\']',)
# Traceback (most recent call last):
#   File "/Users/baleria/anaconda3/lib/python3.7/site-packages/telebot/util.py", line 59, in run
#     task(*args, **kwargs)
#   File "/Users/baleria/anaconda3/lib/python3.7/site-packages/telebot/__init__.py", line 276, in __retrieve_updates
#     updates = self.get_updates(offset=(self.last_update_id + 1), timeout=timeout)
#   File "/Users/baleria/anaconda3/lib/python3.7/site-packages/telebot/__init__.py", line 246, in get_updates
#     json_updates = apihelper.get_updates(self.token, offset, limit, timeout, allowed_updates)
#   File "/Users/baleria/anaconda3/lib/python3.7/site-packages/telebot/apihelper.py", line 180, in get_updates
#     return _make_request(token, method_url, params=payload)
#   File "/Users/baleria/anaconda3/lib/python3.7/site-packages/telebot/apihelper.py", line 56, in _make_request
#     return _check_result(method_name, result)['result']
#   File "/Users/baleria/anaconda3/lib/python3.7/site-packages/telebot/apihelper.py", line 75, in _check_result
#     raise ApiException(msg, method_name, result)
# telebot.apihelper.ApiException: A request to the Telegram API was unsuccessful. The server returned HTTP 409 Conflict. Response body:
# [b'{"ok":false,"error_code":409,"description":"Conflict: terminated by other getUpdates request; make sure that only one bot instance is running"}']
# "
# 2019-07-19 10:45:59,883 (util.py:65 PollingThread) ERROR - TeleBot: "ApiException occurred, args=('A request to the Telegram API was unsuccessful. The server returned HTTP 409 Conflict. Response body:\n[b\'{"ok":false,"error_code":409,"description":"Conflict: terminated by other getUpdates request; make sure that only one bot instance is running"}\']',)
# Traceback (most recent call last):
#   File "/Users/baleria/anaconda3/lib/python3.7/site-packages/telebot/util.py", line 59, in run
#     task(*args, **kwargs)
#   File "/Users/baleria/anaconda3/lib/python3.7/site-packages/telebot/__init__.py", line 276, in __retrieve_updates
#     updates = self.get_updates(offset=(self.last_update_id + 1), timeout=timeout)
#   File "/Users/baleria/anaconda3/lib/python3.7/site-packages/telebot/__init__.py", line 246, in get_updates
#     json_updates = apihelper.get_updates(self.token, offset, limit, timeout, allowed_updates)
#   File "/Users/baleria/anaconda3/lib/python3.7/site-packages/telebot/apihelper.py", line 180, in get_updates
#     return _make_request(token, method_url, params=payload)
#   File "/Users/baleria/anaconda3/lib/python3.7/site-packages/telebot/apihelper.py", line 56, in _make_request
#     return _check_result(method_name, result)['result']
#   File "/Users/baleria/anaconda3/lib/python3.7/site-packages/telebot/apihelper.py", line 75, in _check_result
#     raise ApiException(msg, method_name, result)
# telebot.apihelper.ApiException: A request to the Telegram API was unsuccessful. The server returned HTTP 409 Conflict. Response body:
# [b'{"ok":false,"error_code":409,"description":"Conflict: terminated by other getUpdates request; make sure that only one bot instance is running"}']
# "
# 2019-07-19 10:46:00,002 (util.py:65 PollingThread) ERROR - TeleBot: "ApiException occurred, args=('A request to the Telegram API was unsuccessful. The server returned HTTP 409 Conflict. Response body:\n[b\'{"ok":false,"error_code":409,"description":"Conflict: terminated by other getUpdates request; make sure that only one bot instance is running"}\']',)
# Traceback (most recent call last):
#   File "/Users/baleria/anaconda3/lib/python3.7/site-packages/telebot/util.py", line 59, in run
#     task(*args, **kwargs)
#   File "/Users/baleria/anaconda3/lib/python3.7/site-packages/telebot/__init__.py", line 276, in __retrieve_updates
#     updates = self.get_updates(offset=(self.last_update_id + 1), timeout=timeout)
#   File "/Users/baleria/anaconda3/lib/python3.7/site-packages/telebot/__init__.py", line 246, in get_updates
#     json_updates = apihelper.get_updates(self.token, offset, limit, timeout, allowed_updates)
#   File "/Users/baleria/anaconda3/lib/python3.7/site-packages/telebot/apihelper.py", line 180, in get_updates
#     return _make_request(token, method_url, params=payload)
#   File "/Users/baleria/anaconda3/lib/python3.7/site-packages/telebot/apihelper.py", line 56, in _make_request
#     return _check_result(method_name, result)['result']
#   File "/Users/baleria/anaconda3/lib/python3.7/site-packages/telebot/apihelper.py", line 75, in _check_result
#     raise ApiException(msg, method_name, result)
# telebot.apihelper.ApiException: A request to the Telegram API was unsuccessful. The server returned HTTP 409 Conflict. Response body:
# [b'{"ok":false,"error_code":409,"description":"Conflict: terminated by other getUpdates request; make sure that only one bot instance is running"}']
# "

# %%
@myBot.message_handler(commands=['info'])
def ask(message):
    sent = myBot.send_message(message.chat.id, 'Enter stock ticker. Enter /tickers to view ticker list then enter /info to return.')
    myBot.register_next_step_handler(sent, stockInfo)
def stockInfo(message):
    # optional: open('entry.txt', 'w').write(str(message.chat.id) + ' | ' + message.text + '||')
    myBot.send_message(message.chat.id,ListofDict[Dictfortickers[message.text]])

# %%
print("ITM \nITM2")
# Out:
# ITM
# ITM2

# %%
commandList = [1,2,3]

for i in commandList:
    def function(i):
        return "word" + str(i)
    
function(1) + function(2) + function(3)
# Out:
# 'word1word2word3'

# %%
import telebot
from telebot import types

bot = telebot.TeleBot("849789059:AAHGJ_-j5DYZtZl5ZdRkHlHFzondHxAP9QI")

@bot.message_handler(commands=['start'])
def start(message):
  sent = bot.send_message(message.chat.id, 'Please describe your problem.')
  bot.register_next_step_handler(sent, hello)

def hello(message):
    open('problem.txt', 'w').write(str(message.chat.id) + ' | ' + message.text + '||')
    bot.send_message(str(message.chat.id), 'Thank you!')
    bot.send_message(message.chat.id,str(message.chat.id) + ' | ' + message.text)

bot.polling()

# %%
mainDict = {"Bob":52.5,"Lisa":101.5,"Carl":10.4}
# assume this to be the main dict of everything

tickerList = mainDict.keys()
# make a list here of the tickers in the json-derived line

# %%
print("\n".join(tickerList))
# Out:
# Bob
# Lisa
# Carl
