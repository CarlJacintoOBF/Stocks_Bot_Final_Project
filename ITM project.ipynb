# %%
pip install gspread oauth2client
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Yo so just remember:
# 1. This is a list of dictionaries so use [int] first to call the list then the name of what you're looking for["string"]
# 2. After installing the first part of this code (pip install) you don't need to run it anymore (also restart the kernel when you install it so everything can be useable
# 3. Pretty printer is optional but I think it wil be very useful for you if you want to view the data properly =)))
# 4. Also editing and using this file requires internet

# %%
import gspread
from oauth2client.service_account import ServiceAccountCredentials
import pprint

# %%
scope = ['https://spreadsheets.google.com/feeds','https://www.googleapis.com/auth/drive']
creds = ServiceAccountCredentials.from_json_keyfile_name('My Project 21738-4d265ae50b52.json', scope)
client = gspread.authorize(creds)

# %%
sheet = client.open('Stock Market: Dow Jones').sheet1
sheet.get_all_records()
# Out:
# [{'Symbol': 'MMM',
#   'Name': '3M Company',
#   'Price': 174.67,
#   'Price Open': 176.35,
#   'Close Yestersay': 176.49,
#   'High': 176.49,
#   'Low': 174.1,
#   '52-Week High': 219.75,
#   '52-Week Low': 159.32,
#   'Change': -1.82,
#   'Change in Percent': -1.03,
#   'Beta Value': 1.09,
#   'Volume': 2947472,
#   'Volume Average': 2695546,
#   'Price-Earning Ratio': 19.03,
#   'Earnings per Share': 9.18,
#   'Market Cap': 100684503034,
#   'Shares': 576427000,
#   'Currency': 'USD',
#   'Data Delay': 0,
#   '4 Weeks Ago': '#N/A',
#   '': '',
#   '3 Weeks Ago': '#N/A',
#   '2 Weeks Ago': '#N/A',
#   '1 Week Ago': '#N/A',
#   'Time': '7/18/2019 11:32:38',
#   '(Slider)': '/'},
#  {'Symbol': '',
#   'Name': '',
#   'Price': '',
#   'Price Open': '',
#   'Close Yestersay': '',
#   'High': '',
#   'Low': '',
#   '52-Week High': '',
#   '52-Week Low': '',
#   'Change': '',
#   'Change in Percent': '',
#   'Beta Value': '',
#   'Volume': '',
#   'Volume Average': '',
# ...

# %%
pp = pprint.PrettyPrinter()
snaky = sheet.get_all_records()
pp.pprint(snaky)
# Out:
# [{'': '',
#   '(Slider)': '/',
#   '1 Week Ago': '#N/A',
#   '2 Weeks Ago': '#N/A',
#   '3 Weeks Ago': '#N/A',
#   '4 Weeks Ago': '#N/A',
#   '52-Week High': 219.75,
#   '52-Week Low': 159.32,
#   'Beta Value': 1.09,
#   'Change': -1.82,
#   'Change in Percent': -1.03,
#   'Close Yestersay': 176.49,
#   'Currency': 'USD',
#   'Data Delay': 0,
#   'Earnings per Share': 9.18,
#   'High': 176.49,
#   'Low': 174.1,
#   'Market Cap': 100684503034,
#   'Name': '3M Company',
#   'Price': 174.67,
#   'Price Open': 176.35,
#   'Price-Earning Ratio': 19.03,
#   'Shares': 576427000,
#   'Symbol': 'MMM',
#   'Time': '7/18/2019 10:06:06',
#   'Volume': 2947472,
#   'Volume Average': 2695546},
#  {'': '',
#   '(Slider)': '/',
#   '1 Week Ago': '',
#   '2 Weeks Ago': '',
#   '3 Weeks Ago': '',
#   '4 Weeks Ago': '',
#   '52-Week High': '',
#   '52-Week Low': '',
#   'Beta Value': '',
#   'Change': '',
#   'Change in Percent': '',
#   'Close Yestersay': '',
#   'Currency': '',
#   'Data Delay': '',
# ...

# %%
snaky
# Out:
# [{'Symbol': 'MMM',
#   'Name': '3M Company',
#   'Price': 174.67,
#   'Price Open': 176.35,
#   'Close Yestersay': 176.49,
#   'High': 176.49,
#   'Low': 174.1,
#   '52-Week High': 219.75,
#   '52-Week Low': 159.32,
#   'Change': -1.82,
#   'Change in Percent': -1.03,
#   'Beta Value': 1.09,
#   'Volume': 2947472,
#   'Volume Average': 2695546,
#   'Price-Earning Ratio': 19.03,
#   'Earnings per Share': 9.18,
#   'Market Cap': 100684503034,
#   'Shares': 576427000,
#   'Currency': 'USD',
#   'Data Delay': 0,
#   '4 Weeks Ago': '#N/A',
#   '': '',
#   '3 Weeks Ago': '#N/A',
#   '2 Weeks Ago': '#N/A',
#   '1 Week Ago': '#N/A',
#   'Time': '7/18/2019 10:06:06',
#   '(Slider)': '/'},
#  {'Symbol': '',
#   'Name': '',
#   'Price': '',
#   'Price Open': '',
#   'Close Yestersay': '',
#   'High': '',
#   'Low': '',
#   '52-Week High': '',
#   '52-Week Low': '',
#   'Change': '',
#   'Change in Percent': '',
#   'Beta Value': '',
#   'Volume': '',
#   'Volume Average': '',
# ...

# %%
snaky["Symbol"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-3bb1318a6ad0> in <module>
# ----> 1 snaky["Symbol"]
#
# TypeError: list indices must be integers or slices, not str

# %%
list(snaky[])
